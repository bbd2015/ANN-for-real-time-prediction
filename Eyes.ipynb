# %%
from numpy import genfromtxt
import numpy as np
import pandas as pd

#my_data = pd.read_csv("Eyes.csv")
#my_data = np.loadtxt('Eyes.csv', delimiter='\n')
f = open('open.csv', 'r')
my_data = f.readlines()
a = []


#my_data = 
#my_data.split('|')[1]
#print(my_data)


num_lines = int(sum(1 for line in open('open.csv')))
for i in range(num_lines):
    data = my_data[i]
    a.append(data.split(',')[1])
    first = False

#print(a)
num_rows = int(num_lines/16)

b = np.zeros(shape=(num_rows,16))
k = 0

for i in range(num_rows):
    for j in range(16): 
       
        #print(b)
        
        b[i,j] = a[k]
        k = k + 1
        
        
print(b)
        


#print(int(num_rows))
# Out:
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
# ...

# %%
# Opening a csv file for reading
f = open('openrows.csv', 'w')


def readToCsv(data):
    #rows = [[row[0]], [row[1]], [row[2]], [row[3]], [row[4]], [row[5]], [row[6]], [row[7]], [row[8]], [row[9]], [row[10]], [row[11]], [row[12]], [row[13]], [row[14]], [row[15]]]
    df = pd.DataFrame(data)
    df.to_csv(f, header=False)
    #dataset = pd.read_csv("output.csv")
    # adding column labels
    #dataset.columns=['Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8']


readToCsv(b)

# %%
import pandas as pd
import numpy as np

# eys file 

eyes = pd.read_csv("eyes.csv")

dataset = eyes
#eyes.head

#(np.reshape(eyes.values,(2,16)))

f = open('Eyes.csv', 'r')
my_data = f.readlines()
a = []

first = True
last = False

num_lines = int(sum(1 for line in open('Eyes.csv')))
for i in range(num_lines):
    if(i%16 === 0 and first == False and last == False):
        a.append(data.split(',')[2])
        print(data.split(',')[2])
    else:
        data = my_data[i]
        a.append(data.split(',')[1])
        first = False
        

num_rows = int(num_lines/16)

b = np.zeros(shape=(num_rows,17))
k = 0

for i in range(num_rows):
    for j in range(17):
        print

#data = np.swapaxes(data,0,1)

dataset.head
#transpose value 0-15 to row 1. 
#transpoe value 16 to row 2 (0-1)

#eyesT = eyes.T

dataset.columns=['Channel','Value','State']


dataset.head(900)
#eyesT.head
# Out:
#      Channel         Value  State
# 0          1  1.706000e-03      1
# 1          2  4.842000e-05      1
# 2          3  3.232000e-05      1
# 3          4 -1.279000e-04      1
# 4          5  5.563000e-06      1
# 5          6  1.147000e-05      1
# 6          7 -6.498000e-05      1
# 7          8  1.624000e-03      1
# 8          9 -1.977000e-03      1
# 9         10  2.198000e-06      1
# 10        11 -1.448000e-06      1
# 11        12 -2.598000e-04      1
# 12        13  1.395000e-05      1
# 13        14 -4.492000e-05      1
# 14        15  1.442000e-05      1
# 15         0 -1.334000e-03      1
# 16         1  4.351000e-04      1
# 17         2 -1.692000e-04      1
# 18         3  8.194000e-05      1
# 19         4 -1.719000e-04      1
# 20         5  3.408000e-05      1
# 21         6 -3.613000e-05      1
# 22         7 -4.685000e-05      1
# 23         8 -5.554000e-03      1
# 24         9  1.247000e-03      1
# 25        10 -6.196000e-05      1
# ...

# %%
# Remove missing values
dataset = dataset.dropna()

dataset["Channel1"] = dataset["Channel"][dataset["Channel"] == 0] 
dataset["Channel2"] = dataset["Channel"][dataset["Channel"] == 1] 
dataset["Channel3"] = dataset["Channel"][dataset["Channel"] == 2] 
dataset["Channel4"] = dataset["Channel"][dataset["Channel"] == 3] 
dataset["Channel5"] = dataset["Channel"][dataset["Channel"] == 4] 
dataset["Channel6"] = dataset["Channel"][dataset["Channel"] == 5] 
dataset["Channel7"] = dataset["Channel"][dataset["Channel"] == 6] 
dataset["Channel8"] = dataset["Channel"][dataset["Channel"] == 7] 
dataset["Channel9"] = dataset["Channel"][dataset["Channel"] == 8] 
dataset["Channel10"] = dataset["Channel"][dataset["Channel"] == 9] 
dataset["Channel11"] = dataset["Channel"][dataset["Channel"] == 10] 
dataset["Channel12"] = dataset["Channel"][dataset["Channel"] == 11] 
dataset["Channel13"] = dataset["Channel"][dataset["Channel"] == 12] 
dataset["Channel14"] = dataset["Channel"][dataset["Channel"] == 13] 
dataset["Channel5"] = dataset["Channel"][dataset["Channel"] == 14] 
dataset["Channel6"] = dataset["Channel"][dataset["Channel"] == 15] 

dataset.head(200)


# make channel rows

#dataset["Channel"][dataset["Channel"] == 2] = dataset["Channel2"]
#dataset["Channel"][dataset["Channel"] == 3] = dataset["Channel3"]
#dataset["Channel"][dataset["Channel"] == 4] = dataset["Channel4"]
#dataset["Channel"][dataset["Channel"] == 5] = dataset["Channel5"]
#dataset["Channel"][dataset["Channel"] == 6] = dataset["Channel6"]
#dataset["Channel"][dataset["Channel"] == 7] = dataset["Channel7"]
#dataset["Channel"][dataset["Channel"] == 8] = dataset["Channel8"]
#dataset["Channel"][dataset["Channel"] == 9] = dataset["Channel9"]
#dataset["Channel"][dataset["Channel"] == 10] = dataset["Channel10"]
#dataset["Channel"][dataset["Channel"] == 11] = dataset["Channel11"]
#dataset["Channel"][dataset["Channel"] == 12] = dataset["Channel12"]
#dataset["Channel"][dataset["Channel"] == 13] = dataset["Channel13"]
#dataset["Channel"][dataset["Channel"] == 14] = dataset["Channel14"]
#dataset["Channel"][dataset["Channel"] == 15] = dataset["Channel15"]
#dataset["Channel"][dataset["Channel"] == 16] = dataset["Channel16"]

# change rest values to
#dataset["Channel"][dataset["Mark"] == "REST"] = 0
#dataset["Mark"][dataset["Mark"] == "ADDITION"] = 1
#dataset["Mark"][dataset["Mark"] == "PASSTHOUGHT"] = 2
#dataset["Mark"][dataset["Mark"] == "JUNK"] = 3

# remove the JUNK data
#dataset = dataset[dataset.Mark != 2]
#dataset = dataset[dataset.Mark != 3]
# Out:
#      Channel     Value  State  Channel1  Channel2  Channel3  Channel4  \
# 0          1  0.001706      1       NaN       1.0       NaN       NaN
# 1          2  0.000048      1       NaN       NaN       2.0       NaN
# 2          3  0.000032      1       NaN       NaN       NaN       3.0
# 3          4 -0.000128      1       NaN       NaN       NaN       NaN
# 4          5  0.000006      1       NaN       NaN       NaN       NaN
# 5          6  0.000011      1       NaN       NaN       NaN       NaN
# 6          7 -0.000065      1       NaN       NaN       NaN       NaN
# 7          8  0.001624      1       NaN       NaN       NaN       NaN
# 8          9 -0.001977      1       NaN       NaN       NaN       NaN
# 9         10  0.000002      1       NaN       NaN       NaN       NaN
# 10        11 -0.000001      1       NaN       NaN       NaN       NaN
# 11        12 -0.000260      1       NaN       NaN       NaN       NaN
# ...

# %%
# Remove missing values
dataset = dataset.dropna()

# remove the JUNK data
#dataset = dataset[dataset.Mark != 2]
#dataset = dataset[dataset.Mark != 3]

# shuffle the data
dataset = dataset.sample(frac=1)

#Using the index:

#df[1:4,]
#Where the values in the parentheses can be interpreted as either logical, numeric, or character (matching the respective names):

#df[row.index, column.index]


X = np.array(dataset.ix[:, :16])

Y = np.array([[1,0] if i == 0 else [0,1] for i in dataset.ix[:, :17]])

# Dropout - the number of neurons removed at each layers, who are readded when testing
# Batch size - the number of data points added at each time, affects training time
# Epochs - the number of training/test sessions

# create model
model = Sequential()
model.add(BatchNormalization(input_shape=(52,)))
model.add(Dropout(0.1))
model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))

model.add(Dense(2, kernel_initializer='uniform', activation='softmax'))
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
# Fit the model
history = model.fit(X, Y, validation_split=0.5, epochs=250, batch_size=25, verbose=0)
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-5a1e9db4aac9> in <module>()
#      27
#      28 # create model
# ---> 29 model = Sequential()
#      30 model.add(BatchNormalization(input_shape=(52,)))
#      31 model.add(Dropout(0.1))
#
# NameError: name 'Sequential' is not defined

# %%
from keras.models import model_from_json

# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
