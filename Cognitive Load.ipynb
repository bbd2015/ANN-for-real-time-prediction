# %% [markdown]
# # Data Acquisition
# To get data acquisition.
#
# 1. Plugin the serial port usb.
# 2. Press the play buttin called "start recording and data acquisition"
# 3. Run python3 samImagentRealtime.py 1 in this folder
# 4. The data will be collected to a mysql database.

# %% [markdown]
# # This is a file for working with cognitive load data captured using FNIRS
# https://en.wikipedia.org/wiki/Functional_near-infrared_spectroscopy
#
# The data is part of two different datasets made by Tomoki Shibata with the purpose of measuring cognitive load.
#
# The two experiments are.
#
# ## N-back task
# Four participants performed an N-back task where the level of N-back used to determine the cognitive load.
# ## Card sorting task
# Four participants performed a card sorting task

# %% [markdown]
# # This is already done
# ## Preparing files for being used
# #  inside the directory for each user
# ```cat *_1 > Easy
# cat *_2 > Difficult ```
# # for the set users
# ``` cat *_0 > Easy
# cat *_1 > Difficult ```
# # for all back_N users
# # adding the labels for easy and Difficult
# ``` awk '{printf("%s,0\n",$0)}' Easy > EasyL
# awk '{printf("%s,1\n",$0)}' Difficult > DifficultL ```
# # making into one file
# ``` cat EasyL DifficultL > CognitiveLoad ```

# %%
import pandas as pd

#users

# n-back
user3_n = pd.read_csv("OUT/p003-p1-n/CognitiveLoad")
user4_n = pd.read_csv("OUT/p004-p1-n/CognitiveLoad")
user6_n = pd.read_csv("OUT/p006-p1-n/CognitiveLoad")
user8_n = pd.read_csv("OUT/p008-p1-n/CognitiveLoad")

three_n = pd.read_csv("OUT/master/three_n")

# master n-back file
master_n = pd.read_csv("OUT/master/CognitiveLoadMasterN")

# card sorting
user3_c = pd.read_csv("OUT/p003-p1-s/CognitiveLoad")
user4_c = pd.read_csv("OUT/p004-p1-s/CognitiveLoad")
user6_c = pd.read_csv("OUT/p006-p1-s/CognitiveLoad")
user8_c = pd.read_csv("OUT/p008-p1-s/CognitiveLoad")

# master sorting file
master_s = pd.read_csv("OUT/master/CognitiveLoadMasterS")

# eyes file 
eyes = pd.read_csv("eyes.csv")

# test files
test1 = pd.read_csv("arithmetic.csv")

#
kevin = pd.read_csv("KevinState1")

kevindefault = pd.read_csv("KevinDefault1")
kevintask = pd.read_csv("KevinTask1")

# default mode network
#default = pd.read_csv("default1.csv")

# task positive network
#task = pd.read_csv("task1.csv")
#default = pd.read_csv("default")

taskdefault = pd.read_csv("taskdefault1.csv")

#task.columns = ['Timestamp','Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8', 'Oxy9', 'DeOxy9', 'Oxy10', 'DeOxy10', 'Oxy11', 'DeOxy11', 'Oxy12', 'DeOxy12', 'State']
#default.columns = ['Timestamp','Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8', 'Oxy9', 'DeOxy9', 'Oxy10', 'DeOxy10', 'Oxy11', 'DeOxy11', 'Oxy12', 'DeOxy12', 'State']


#task['State'] = [0] * len(task)
#default['State'] = [1] * len(task)

#state = pd.read_csv("state")

# merge two datasets
#taskdefault = pd.concat([task, default])

# Remove missing values
#state = state.dropna()

# decide which dataset to load

eyes = pd.read_csv("OUT/eyes/eyesopenclosed2.csv")

dataset = eyes



# adding column labels
#dataset.columns=['Timestamp','x1','x2','x3','Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8', 'CognitiveLoad']

#kevintask.columns = ['Timestamp','Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8', 'CognitiveLoad']
#dataset.columns = ['Timestamp','Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8', 'CognitiveLoad']


#kevindefault["CognitiveLoad"][kevindefault["CognitiveLoad"] == 0] = 1


#newkevin = pd.concat([kevintask, kevindefault])

#dataset = newkevin

dataset.columns = ['Timestamp','Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8', 'State']
#task.columns = ['Timestamp','Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8', 'Oxy9', 'DeOxy9', 'Oxy10', 'DeOxy10', 'Oxy11', 'DeOxy11', 'Oxy12', 'DeOxy12', 'State']
#dataset.columns = ['Timestamp','Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8', 'Oxy9', 'DeOxy9', 'Oxy10', 'DeOxy10', 'Oxy11', 'DeOxy11', 'Oxy12', 'DeOxy12', 'State']



# get the head of the dataset data
#dataset.head
#kevintask.head

#task.head
#default.head

#X = np.column_stack((dataset["Oxy1"], dataset["Oxy2"], dataset["Oxy3"], dataset["Oxy4"], dataset["Oxy5"], dataset["Oxy6"], dataset["Oxy7"], dataset["Oxy8"], dataset["DeOxy1"], dataset["DeOxy2"], dataset["DeOxy3"], dataset["DeOxy4"], dataset["DeOxy5"], dataset["DeOxy6"], dataset["DeOxy7"], dataset["DeOxy8"] ))

# for use with all channels
#AllChannels = np.column_stack((dataset["Oxy1"], dataset["Oxy2"], dataset["Oxy3"], dataset["Oxy4"], dataset["Oxy5"], dataset["Oxy6"], dataset["Oxy7"], dataset["Oxy8"], dataset["Oxy9"], dataset["Oxy10"], dataset["Oxy11"], dataset["Oxy12"], dataset["DeOxy1"], dataset["DeOxy2"], dataset["DeOxy3"], dataset["DeOxy4"], dataset["DeOxy5"], dataset["DeOxy6"], dataset["DeOxy7"], dataset["DeOxy8"], dataset["DeOxy9"], dataset["DeOxy10"], dataset["DeOxy11"], dataset["DeOxy12"]))

# using Oxygenation channel 
# input shape is the number of variables inside the X array

#X = np.array(dataset.ix[:,4], dataset.ix[:,5], dataset.ix[:,6], dataset.ix[:,7], dataset.ix[:,8], dataset.ix[:,9], dataset.ix[:,10], dataset.ix[:,11], dataset.ix[:,12], dataset.ix[:,13], dataset.ix[:,14], dataset.ix[:,15], dataset.ix[:,16], dataset.ix[:,17], dataset.ix[:,18], dataset.ix[:,19])
# for use with 26 channels
# = np.array([[1,0] if i == 0 else [0,1] for i in dataset.State])
#Y = dataset.CognitiveLoad



#kevindefault.head

# %%
dataset.columns
#task.columns
# Out:
# Index(['Timestamp', 'Oxy1', 'DeOxy1', 'Oxy2', 'DeOxy2', 'Oxy3', 'DeOxy3',
#        'Oxy4', 'DeOxy4', 'Oxy5', 'DeOxy5', 'Oxy6', 'DeOxy6', 'Oxy7', 'DeOxy7',
#        'Oxy8', 'DeOxy8', 'State'],
#       dtype='object')

# %% [markdown]
# ## This code makes a neural network predictions based on Tomokis cognitive load dataset
# ### You can change the different parameters to try to improve your prediction

# %%
# Visualize training history
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization
from keras.layers import Dropout
from keras.optimizers import RMSprop
from keras import optimizers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import numpy
import keras

# Remove warnings
import warnings
warnings.filterwarnings('ignore')

# decide dataset


# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# Remove missing values
dataset = dataset.dropna()

# shuffle the data
dataset = dataset.sample(frac=1)

# for use with two channels
X = np.column_stack((dataset["Oxy1"], dataset["Oxy2"], dataset["Oxy3"], dataset["Oxy4"], dataset["Oxy5"], dataset["Oxy6"], dataset["Oxy7"], dataset["Oxy8"], dataset["DeOxy1"], dataset["DeOxy2"], dataset["DeOxy3"], dataset["DeOxy4"], dataset["DeOxy5"], dataset["DeOxy6"], dataset["DeOxy7"], dataset["DeOxy8"] ))

#X = dataset["Oxy3"]

# for use with all channels
#AllChannels = np.column_stack((dataset["Oxy1"], dataset["Oxy2"], dataset["Oxy3"], dataset["Oxy4"], dataset["Oxy5"], dataset["Oxy6"], dataset["Oxy7"], dataset["Oxy8"], dataset["Oxy9"], dataset["Oxy10"], dataset["Oxy11"], dataset["Oxy12"], dataset["DeOxy1"], dataset["DeOxy2"], dataset["DeOxy3"], dataset["DeOxy4"], dataset["DeOxy5"], dataset["DeOxy6"], dataset["DeOxy7"], dataset["DeOxy8"], dataset["DeOxy9"], dataset["DeOxy10"], dataset["DeOxy11"], dataset["DeOxy12"]))

# using Oxygenation channel 
# input shape is the number of variables inside the X array
#X = Oxy1_2
#X = np.array(dataset.ix[:,4], dataset.ix[:,5], dataset.ix[:,6], dataset.ix[:,7], dataset.ix[:,8], dataset.ix[:,9], dataset.ix[:,10], dataset.ix[:,11], dataset.ix[:,12], dataset.ix[:,13], dataset.ix[:,14], dataset.ix[:,15], dataset.ix[:,16], dataset.ix[:,17], dataset.ix[:,18], dataset.ix[:,19])
# for use with 26 channels
Y = np.array([[1,0] if i == 0 else [0,1] for i in dataset.State])
#Y = np.array([[1,0] if i == 0 else [0,1] for i in dataset.CognitiveLoad])


# Dropout - the number of neurons removed at each layers, who are readded when testing
# Batch size - the number of data points added at each time, affects training time
# Epochs - the number of training/test sessions
#sideprobe = task
#frontal = default

#y = sum(sideprobe) / sum(frontal)

#sideprobe = 5
#frontal = 2

#difference = 5 / 2

#difference = sum(sideprobe) - deoxygenation(sideprobe) / sum(frontal)


# create model
model = Sequential()

# batchnormalization, makes the value fit between 0-1

#for use with 3 sensors
#model.add(BatchNormalization(input_shape=(24, )))
model.add(BatchNormalization(input_shape=(16, )))
model.add(Dropout(0.2))
model.add(Dense(100, init="normal", activation='relu'))
model.add(Dense(100, init="normal", activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(100, init="normal", activation='relu'))
model.add(Dense(100, init="normal", activation='relu'))


#model.add(Dense(100, init='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))

# output layer guesses low or high cognitive load
model.add(Dense(2, init="normal", activation='softmax'))
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
# Fit the model
history = model.fit(X, Y, validation_split=0.5, nb_epoch=5, batch_size=5, verbose=1)

# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()


# save the trained model
from keras.models import model_from_json

# serialize model to JSON
model_json = model.to_json()
with open("eyes2.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("eyes2.h5")
print("Saved model to disk")
# Out:
# Train on 1585 samples, validate on 1585 samples
# Epoch 1/5
# 1585/1585 [==============================] - 1s - loss: 0.0478 - acc: 0.9521 - val_loss: 0.0115 - val_acc: 1.0000
# Epoch 2/5
# 1585/1585 [==============================] - 1s - loss: 0.0337 - acc: 0.9647 - val_loss: 1.1688e-06 - val_acc: 1.0000
# Epoch 3/5
# 1585/1585 [==============================] - 1s - loss: 0.0394 - acc: 0.9596 - val_loss: 0.0010 - val_acc: 1.0000
# Epoch 4/5
# 1585/1585 [==============================] - 1s - loss: 0.0328 - acc: 0.9640 - val_loss: 3.1589e-07 - val_acc: 1.0000
# Epoch 5/5
# 1585/1585 [==============================] - 1s - loss: 0.0324 - acc: 0.9659 - val_loss: 1.3849e-05 - val_acc: 1.0000
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Saved model to disk

# %% [markdown]
# # Save the weight and biases to JSON for use in FNIR filter

# %%
from keras.models import model_from_json

# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")

# later...
 
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")


# adding x and y
dataset = user3_n

# adding column labels
dataset.columns=['Timestamp','x1','x2','x3','Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8', 'CognitiveLoad']

Oxy1_2 = np.column_stack((dataset["Oxy1"], dataset["Oxy2"], dataset["Oxy3"], dataset["Oxy4"], dataset["Oxy5"], dataset["Oxy6"], dataset["Oxy7"], dataset["Oxy8"], dataset["DeOxy1"], dataset["DeOxy2"], dataset["DeOxy3"], dataset["DeOxy4"], dataset["DeOxy5"], dataset["DeOxy6"], dataset["DeOxy7"], dataset["DeOxy8"] ))

X = Oxy1_2
Y = np.array([[1,0] if i == 0 else [0,1] for i in dataset.CognitiveLoad])


# evaluate loaded model on test data
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
score = loaded_model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# Saved model to disk
# Loaded model from disk
# acc: 51.01%

# %%
# Create first network with Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = user4_n

# Remove missing values
dataset = dataset.dropna()

# shuffle the data
dataset = dataset.sample(frac=1)

# Oxy channel one and two
#Oxy1_2 = np.array(dataset["Oxy2"], dataset["Oxy3"])

Oxy1_2 = np.column_stack((dataset["Oxy1"], dataset["Oxy2"], dataset["Oxy3"], dataset["Oxy4"], dataset["Oxy5"], dataset["Oxy6"], dataset["Oxy7"], dataset["Oxy8"], dataset["DeOxy1"], dataset["DeOxy2"], dataset["DeOxy3"], dataset["DeOxy4"], dataset["DeOxy5"], dataset["DeOxy6"], dataset["DeOxy7"], dataset["DeOxy8"] ))

#Oxy1_2 = np.column_stack((dataset["Oxy2"], dataset["Oxy2"]))

# using Oxygenation channel 
# input shape is the number of variables inside the X array
X = Oxy1_2
#X = np.array(dataset.ix[:,4], dataset.ix[:,5], dataset.ix[:,6], dataset.ix[:,7], dataset.ix[:,8], dataset.ix[:,9], dataset.ix[:,10], dataset.ix[:,11], dataset.ix[:,12], dataset.ix[:,13], dataset.ix[:,14], dataset.ix[:,15], dataset.ix[:,16], dataset.ix[:,17], dataset.ix[:,18], dataset.ix[:,19])
Y = np.array([[1,0] if i == 0 else [0,1] for i in dataset.CognitiveLoad])


# Dropout - the number of neurons removed at each layers, who are readded when testing
# Batch size - the number of data points added at each time, affects training time
# Epochs - the number of training/test sessions

# create model
model = Sequential()

# batchnormalization, makes the value fit between 0-1
model.add(BatchNormalization(input_shape=(16, )))
model.add(Dense(100, init="normal", activation='relu'))
model.add(Dense(100, init="normal", activation='relu'))
model.add(Dense(100, init="normal", activation='relu'))
model.add(Dense(100, init="normal", activation='relu'))




#model.add(Dense(100, init='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))
#model.add(Dense(100, kernel_initializer='uniform', activation='relu'))

# output layer guesses low or high cognitive load
model.add(Dense(2, init="normal", activation='softmax'))
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
# Fit the model
#history = model.fit(X, Y, validation_split=0.3, nb_epoch=15, batch_size=50, verbose=1)

# Fit the model
model.fit(X, Y, nb_epoch=25, batch_size=100,  verbose=2)
# calculate predictions
predictions = model.predict(X)
# round predictions
rounded = [round(x[0]) for x in predictions]
print(rounded)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/birgermoell/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'Oxy1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
model.predict(X)
# Out:
# array([[  9.70122218e-01,   2.98777688e-02],
#        [  9.99318242e-01,   6.81759149e-04],
#        [  2.37774890e-29,   1.00000000e+00],
#        ...,
#        [  9.44264293e-01,   5.57356551e-02],
#        [  9.76404786e-01,   2.35952195e-02],
#        [  9.99780238e-01,   2.19723632e-04]], dtype=float32)

# %%
#!/usr/bin/python
import MySQLdb
import pandas as pd
import numpy as np
from keras.models import model_from_json

# Open the file
f = open('output.csv', 'w')

db = MySQLdb.connect(host="localhost",    # your host, usually localhost
                     user="root",         # your username
                     passwd="",  # your password
                     db="newttt")        # name of the data base

# you must create a Cursor object. It will let
#  you execute all the queries you need
cur = db.cursor()

# Use all the SQL you like
cur.execute("SELECT * FROM REALTIME1")

columns = ['Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8']


#while True:
    # Read the data
#    df = pd.DataFrame((np.array(cur.fetchmany(1000)), columns))
    # We are done if there are no data
#    if len(df) == 0:
#        break
        # Lets write to the file
#    else:
#        df.to_csv(f, header=False)

# later...

# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")



# print all the first cell of all the rows
for row in cur.fetchall():
    rows = [[row[0]], [row[1]], [row[2]], [row[3]], [row[4]], [row[5]], [row[6]], [row[7]], [row[8]], [row[9]], [row[10]], [row[11]], [row[12]], [row[13]], [row[14]], [row[15]]]
    df = pd.DataFrame((np.array(rows)), columns)
    #df.to_csv(f, header=False)
    #dataset = pd.read_csv("output.csv")
    # adding column labels
    #dataset.columns=['Oxy1','DeOxy1','Oxy2','DeOxy2','Oxy3','DeOxy3', 'Oxy4','DeOxy4','Oxy5','DeOxy5','Oxy6','DeOxy6','Oxy7','DeOxy7','Oxy8','DeOxy8']
    print(numpy.transpose(df))
    print("Predicting the value")
    print(loaded_model.predict(numpy.transpose((df))))

    # printing all the channel values
    print("oxy1")
    print (row[0])
    print("deoxy1")
    print (row[1])
    print("oxy2")
    print (row[2])
    print("deoxy2")
    print (row[3])
    print("oxy3")
    print (row[4])
    print("deoxy3")
    print (row[5])
    print("oxy4")
    print (row[6])
    print("deoxy4")
    print (row[7])
    print("oxy5")
    print (row[8])
    print("deoxy5")
    print (row[9])
    print("oxy6")
    print (row[10])
    print("deoxy6")
    print (row[11])
    print("oxy7")
    print (row[12])
    print("deoxy7")
    print (row[13])
    print("oxy8")
    print (row[14])
    print("deoxy8")
    print (row[15])

db.close()

# Clean up
f.close()
cursor.close()
connection.close()
# Out:
# Loaded model from disk
#         Oxy1    DeOxy1        Oxy2      DeOxy2         Oxy3       DeOxy3  \
# 0  -0.002688  0.001489  0.00002554  0.00000466  -0.00005528  0.000004979
#
#          Oxy4       DeOxy4      Oxy5    DeOxy5         Oxy6       DeOxy6  \
# 0  0.00001224  0.000005004  -0.01341  0.002572  -0.00001322  -0.00001693
#
#            Oxy7       DeOxy7         Oxy8       DeOxy8
# 0  -0.000001592  -0.00002241  -0.00000895  0.000001769
# Predicting the value
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-8cc920787154> in <module>()
#      56     print(numpy.transpose(df))
#      57     print("Predicting the value")
# ---> 58     print(loaded_model.predict(numpy.transpose((df))))
#      59
#      60     # printing all the channel values
#
# ...
